# %%
import pandas as pd
import numpy as np
import pickle
import streamlit as st
from sklearn.preprocessing import StandardScaler

## Load the model
model = pickle.load(open('rf.pkl', 'rb'))

#Streamlit app setup
st.set_page_config(page_title='Segmentation of Customers', layout='centered')
st.title('Segmentation of Customers')

st.markdown(
    """
    <style>
    .stApp {
        background-color: #0077b6;
    }
    </style>
    """,
    unsafe_allow_html=True
)
st.write()

def user_input():
    Year_Birth = st.sidebar.number_input('Input Year of Birth',value=1940,step=1,format="%d")
    Education = st.sidebar.selectbox('Education', ['Basic', '2n Cycle', 'Graduation', 'Master', 'PhD'])
    Marital_Status = st.sidebar.selectbox('Marital Status', ['Single', 'Together', 'Married', 'Divorced'])
    Income = st.sidebar.number_input('Input Household Income',value=0,step=1,format="%d")
    Kidhome = st.sidebar.radio('Select Number Of Kids In Household', [0, 1, 2])
    Teenhome = st.sidebar.radio('Select Number Of Teens In Household', [0, 1, 2])
    MntWines = st.sidebar.number_input('Amount spent on Wine in last 2 years',value=0,step=1,format="%d")
    MntFruits = st.sidebar.number_input('Amount spent on Fruits in last 2 years',value=0,step=1,format="%d")
    MntMeatProducts = st.sidebar.number_input('Amount spent on Meat in last 2 years',value=0,step=1,format="%d")
    MntFishProducts = st.sidebar.number_input('Amount spent on Fish in last 2 years',value=0,step=1,format="%d")
    MntSweetProducts = st.sidebar.number_input('Amount spent on Sweet in last 2 years',value=0,step=1,format="%d")
    MntGoldProds = st.sidebar.number_input('Amount spent on Gold in last 2 years',value=0,step=1,format="%d")
    NumWebPurchases = st.sidebar.number_input('Number of purchases made through Company website',value=0,step=1,format="%d")
    NumCatalogPurchases = st.sidebar.number_input('Number of purchases made using a catalogue',value=0,step=1,format="%d")
    NumStorePurchases = st.sidebar.number_input('Number of purchases made directly in store',value=0,step=1,format="%d")

    data = {
        'Year_Birth': Year_Birth,
        'Education': Education,
        'Marital_Status': Marital_Status,
        'Income': Income,
        'Kidhome': Kidhome,
        'Teenhome': Teenhome,
        'MntWines': MntWines,
        'MntFruits': MntFruits,
        'MntMeatProducts': MntMeatProducts,
        'MntFishProducts': MntFishProducts,
        'MntSweetProducts': MntSweetProducts,
        'MntGoldProds': MntGoldProds,
        'NumWebPurchases': NumWebPurchases,
        'NumCatalogPurchases': NumCatalogPurchases,
        'NumStorePurchases': NumStorePurchases
    }

    features = pd.DataFrame(data, index=[0])
    return features

def preprocess_input(features):
    # Encode categorical features
    education_mapping = {'Basic': 0, '2n Cycle': 1, 'Graduation': 2, 'Master': 3, 'PhD': 4}
    marital_status_mapping = {'Single': 0, 'Together': 1, 'Married': 2, 'Divorced': 3}

    features['Education'] = features['Education'].map(education_mapping)
    features['Marital_Status'] = features['Marital_Status'].map(marital_status_mapping)
    
def preprocess_features(features):
    ## Ensure the order of columns is consistent with the training data
    columns_order = ['Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome', 
                     'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 
                     'MntGoldProds', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases']

    features = features[columns_order]
    return features

def cust_segment(features):
     prediction = model.predict(features)
     cluster = ''
     if prediction[0] == 0:
         cluster = 'Cluster 1'
     elif prediction[1] == 1:
         cluster = 'Cluster 2'
     elif prediction[2] == 2:
         cluster = 'Cluster 3'
     return cluster

## Get user input
sub_df = user_input()
processed_sub_df = preprocess_input(sub_df)

## Predict customer segment
if st.button("Segment Customer"):
    segment = cust_segment(processed_sub_df)
    st.write(f'The customer belongs to {segment}')
# Out:
# 2024-09-26 10:27:30.136 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.137 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.644
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\sreet\Documents\anaconda installation\envs\aidl\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-09-26 10:27:30.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.659 Session state does not function when running a script without `streamlit run`
# 2024-09-26 10:27:30.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.691 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.696 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.757 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.762 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.764 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.773 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.774 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.782 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-26 10:27:30.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
